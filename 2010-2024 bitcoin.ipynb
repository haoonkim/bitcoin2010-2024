# %%
import pandas as pd # data pre-processing, CSV file I/O (e.g. pd.read_csv)
import numpy as np # import it for numerical computation on data 
import matplotlib.pyplot as plt ## data viz libraries 
import seaborn as sns

# %%
import os

# %%
df = pd.read_csv(r"/Users/haoonkim/Documents/csv/bitcoin_2010-07-17_2024-05-23.csv")

# %%
df.head(-10)
# Out:
#            Start         End        Open        High         Low       Close  \
# 0     2024-05-22  2024-05-23  70144.6900  70599.9700  69048.6000  69224.9900
# 1     2024-05-21  2024-05-22  71369.7300  71739.1400  69266.3800  70104.4000
# 2     2024-05-20  2024-05-21  66222.4500  71456.5500  66139.6200  71418.1700
# 3     2024-05-19  2024-05-20  66972.6300  67598.3100  66005.3300  66347.0500
# 4     2024-05-18  2024-05-19  66939.8200  67376.4100  66640.0100  66914.5800
# ...          ...         ...         ...         ...         ...         ...
# 5044  2010-07-31  2010-08-01      0.0679      0.0679      0.0679      0.0679
# 5045  2010-07-30  2010-07-31      0.0627      0.0627      0.0627      0.0627
# 5046  2010-07-29  2010-07-30      0.0699      0.0699      0.0699      0.0699
# 5047  2010-07-28  2010-07-29      0.0589      0.0589      0.0589      0.0589
# 5048  2010-07-27  2010-07-28      0.0600      0.0600      0.0600      0.0600
#
#             Volume    Market Cap
# 0     1.161000e+11  1.375970e+12
# 1     1.403673e+11  1.391372e+12
# 2     9.769064e+10  1.332128e+12
# 3     8.441685e+10  1.317072e+12
# 4     9.377570e+10  1.318743e+12
# ...            ...           ...
# 5044  0.000000e+00  0.000000e+00
# 5045  0.000000e+00  0.000000e+00
# 5046  0.000000e+00  0.000000e+00
# 5047  0.000000e+00  0.000000e+00
# 5048  0.000000e+00  0.000000e+00
#
# [5049 rows x 8 columns]

# %%
df.columns
# Out:
# Index(['Start', 'End', 'Open', 'High', 'Low', 'Close', 'Volume', 'Market Cap'], dtype='object')

# %%
df.shape
# Out:
# (5059, 8)

# %%
df.info
# Out:
# <bound method DataFrame.info of            Start         End        Open        High         Low       Close  \
# 0     2024-05-22  2024-05-23  70144.6900  70599.9700  69048.6000  69224.9900
# 1     2024-05-21  2024-05-22  71369.7300  71739.1400  69266.3800  70104.4000
# 2     2024-05-20  2024-05-21  66222.4500  71456.5500  66139.6200  71418.1700
# 3     2024-05-19  2024-05-20  66972.6300  67598.3100  66005.3300  66347.0500
# 4     2024-05-18  2024-05-19  66939.8200  67376.4100  66640.0100  66914.5800
# ...          ...         ...         ...         ...         ...         ...
# 5054  2010-07-21  2010-07-22      0.0792      0.0792      0.0792      0.0792
# 5055  2010-07-20  2010-07-21      0.0747      0.0747      0.0747      0.0747
# 5056  2010-07-19  2010-07-20      0.0808      0.0808      0.0808      0.0808
# 5057  2010-07-18  2010-07-19      0.0858      0.0858      0.0858      0.0858
# 5058  2010-07-17  2010-07-18      0.0500      0.0500      0.0500      0.0500
#
#             Volume    Market Cap
# 0     1.161000e+11  1.375970e+12
# 1     1.403673e+11  1.391372e+12
# 2     9.769064e+10  1.332128e+12
# 3     8.441685e+10  1.317072e+12
# 4     9.377570e+10  1.318743e+12
# ...            ...           ...
# 5054  0.000000e+00  0.000000e+00
# 5055  0.000000e+00  0.000000e+00
# 5056  0.000000e+00  0.000000e+00
# 5057  0.000000e+00  0.000000e+00
# 5058  0.000000e+00  0.000000e+00
#
# [5059 rows x 8 columns]>

# %%
df.describe().T
# Out:
#              count          mean           std   min           25%  \
# Open        5059.0  1.143818e+04  1.684455e+04  0.05  2.294955e+02
# High        5059.0  1.170526e+04  1.723867e+04  0.05  2.326785e+02
# Low         5059.0  1.115841e+04  1.642712e+04  0.05  2.260675e+02
# Close       5059.0  1.145297e+04  1.686624e+04  0.05  2.295640e+02
# Volume      5059.0  2.080825e+10  3.322006e+10  0.00  6.455739e+06
# Market Cap  5059.0  2.151543e+11  3.233431e+11  0.00  3.272665e+09
#
#                      50%           75%           max
# Open        2.506470e+03  1.672368e+04  7.296103e+04
# High        2.581910e+03  1.698132e+04  7.362843e+04
# Low         2.412940e+03  1.648085e+04  7.133336e+04
# Close       2.517590e+03  1.676288e+04  7.308795e+04
# Volume      1.040786e+09  3.342707e+10  2.121515e+11
# Market Cap  4.145427e+10  3.194169e+11  1.428493e+12

# %%
df.dtypes
# Out:
# Start          object
# End            object
# Open          float64
# High          float64
# Low           float64
# Close         float64
# Volume        float64
# Market Cap    float64
# dtype: object

# %%
df['Start'] = df['Start'].astype('datetime64[ns]')

# %%
df['Start'].min()
# Out:
# Timestamp('2010-07-17 00:00:00')

# %%
df['Start'].max()
# Out:
# Timestamp('2024-05-22 00:00:00')

# %%
df['Start']
# Out:
# 0      2024-05-22
# 1      2024-05-21
# 2      2024-05-20
# 3      2024-05-19
# 4      2024-05-18
#           ...
# 5054   2010-07-21
# 5055   2010-07-20
# 5056   2010-07-19
# 5057   2010-07-18
# 5058   2010-07-17
# Name: Start, Length: 5059, dtype: datetime64[ns]

# %%
type(df['Start'][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df.isnull().sum()
# Out:
# Start         0
# End           0
# Open          0
# High          0
# Low           0
# Close         0
# Volume        0
# Market Cap    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.head()
# Out:
#        Start         End      Open      High       Low     Close  \
# 0 2024-05-22  2024-05-23  70144.69  70599.97  69048.60  69224.99
# 1 2024-05-21  2024-05-22  71369.73  71739.14  69266.38  70104.40
# 2 2024-05-20  2024-05-21  66222.45  71456.55  66139.62  71418.17
# 3 2024-05-19  2024-05-20  66972.63  67598.31  66005.33  66347.05
# 4 2024-05-18  2024-05-19  66939.82  67376.41  66640.01  66914.58
#
#          Volume    Market Cap
# 0  1.161000e+11  1.375970e+12
# 1  1.403673e+11  1.391372e+12
# 2  9.769064e+10  1.332128e+12
# 3  8.441685e+10  1.317072e+12
# 4  9.377570e+10  1.318743e+12

# %%
df.tail()
# Out:
#           Start         End    Open    High     Low   Close  Volume  \
# 5054 2010-07-21  2010-07-22  0.0792  0.0792  0.0792  0.0792     0.0
# 5055 2010-07-20  2010-07-21  0.0747  0.0747  0.0747  0.0747     0.0
# 5056 2010-07-19  2010-07-20  0.0808  0.0808  0.0808  0.0808     0.0
# 5057 2010-07-18  2010-07-19  0.0858  0.0858  0.0858  0.0858     0.0
# 5058 2010-07-17  2010-07-18  0.0500  0.0500  0.0500  0.0500     0.0
#
#       Market Cap
# 5054         0.0
# 5055         0.0
# 5056         0.0
# 5057         0.0
# 5058         0.0

# %%
data = df.sort_index(ascending=False).reset_index()

# %%
data.drop('index', axis=1, inplace=True)

# %%
data
# Out:
#           Start         End        Open        High         Low       Close  \
# 0    2010-07-17  2010-07-18      0.0500      0.0500      0.0500      0.0500
# 1    2010-07-18  2010-07-19      0.0858      0.0858      0.0858      0.0858
# 2    2010-07-19  2010-07-20      0.0808      0.0808      0.0808      0.0808
# 3    2010-07-20  2010-07-21      0.0747      0.0747      0.0747      0.0747
# 4    2010-07-21  2010-07-22      0.0792      0.0792      0.0792      0.0792
# ...         ...         ...         ...         ...         ...         ...
# 5054 2024-05-18  2024-05-19  66939.8200  67376.4100  66640.0100  66914.5800
# 5055 2024-05-19  2024-05-20  66972.6300  67598.3100  66005.3300  66347.0500
# 5056 2024-05-20  2024-05-21  66222.4500  71456.5500  66139.6200  71418.1700
# 5057 2024-05-21  2024-05-22  71369.7300  71739.1400  69266.3800  70104.4000
# 5058 2024-05-22  2024-05-23  70144.6900  70599.9700  69048.6000  69224.9900
#
#             Volume    Market Cap
# 0     0.000000e+00  0.000000e+00
# 1     0.000000e+00  0.000000e+00
# 2     0.000000e+00  0.000000e+00
# 3     0.000000e+00  0.000000e+00
# 4     0.000000e+00  0.000000e+00
# ...            ...           ...
# 5054  9.377570e+10  1.318743e+12
# 5055  8.441685e+10  1.317072e+12
# 5056  9.769064e+10  1.332128e+12
# 5057  1.403673e+11  1.391372e+12
# 5058  1.161000e+11  1.375970e+12
#
# [5059 rows x 8 columns]

# %%
data.columns
# Out:
# Index(['Start', 'End', 'Open', 'High', 'Low', 'Close', 'Volume', 'Market Cap'], dtype='object')

# %%
plt.figure(figsize=(20,12))

for index, col in enumerate(['Open', 'High', 'Low', 'Close'], 1):
    plt.subplot(2,2,index)
    plt.plot(df['Start'], df[col])
    plt.title(col)

# %%
data.shape
# Out:
# (5059, 8)

# %%
sample = data[4000:5059]

# %%
# !pip install chart_studio
# !pip install plotly
# Out:
# Requirement already satisfied: chart_studio in /Users/haoonkim/anaconda3/lib/python3.11/site-packages (1.1.0)
# Requirement already satisfied: plotly in /Users/haoonkim/anaconda3/lib/python3.11/site-packages (from chart_studio) (5.9.0)
# Requirement already satisfied: requests in /Users/haoonkim/anaconda3/lib/python3.11/site-packages (from chart_studio) (2.31.0)
# Requirement already satisfied: retrying>=1.3.3 in /Users/haoonkim/anaconda3/lib/python3.11/site-packages (from chart_studio) (1.3.4)
# Requirement already satisfied: six in /Users/haoonkim/anaconda3/lib/python3.11/site-packages (from chart_studio) (1.16.0)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/haoonkim/anaconda3/lib/python3.11/site-packages (from plotly->chart_studio) (8.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/haoonkim/anaconda3/lib/python3.11/site-packages (from requests->chart_studio) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/haoonkim/anaconda3/lib/python3.11/site-packages (from requests->chart_studio) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/haoonkim/anaconda3/lib/python3.11/site-packages (from requests->chart_studio) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/haoonkim/anaconda3/lib/python3.11/site-packages (from requests->chart_studio) (2024.2.2)
# Requirement already satisfied: plotly in /Users/haoonkim/anaconda3/lib/python3.11/site-packages (5.9.0)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/haoonkim/anaconda3/lib/python3.11/site-packages (from plotly) (8.2.2)

# %%
import chart_studio.plotly as py
import plotly.graph_objs as go
import plotly.express as px
from plotly.offline import download_plotlyjs , init_notebook_mode , plot , iplot

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#open high low close value
trace = go.Candlestick(x= sample['Start'], 
               high = sample['High'], 
               open = sample['Open'], 
               close = sample['Close'],
               low = sample['Low'])

# %%
candle_data = [trace]

layout = {
    'title': 'Bitcoin Historical Price',
    'xaxis':{'title':'Data'}
}

# %%
fig = go.Figure(data = candle_data, layout=layout)
fig.update_layout(xaxis_rangeslider_visible = False)
fig.show()
# Out:
# <div>                            <div id="8f0474f6-b107-48bb-90b5-bfc6d7c7a9ab" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8
950357352,37201.84234665862,37784.7229,38131.8236,37937.339,38472.00623585542,38761.9683,36835.9015,37027.78,41653.56035863469,41360.0538,42388.07234245959,43905.99797776678,44082.39258092253,44283.9142,43524.3779183224,42377.6527,42126.3511,42235.5136,42594.94190251804,44602.5315,43997.7116,40491.0412,39976.235950323,40112.559528975085,38464.85279732303,37003.15355791065,38302.8439,37287 ...

# %%
data['Close']
# Out:
# 0           0.0500
# 1           0.0858
# 2           0.0808
# 3           0.0747
# 4           0.0792
#            ...
# 5054    66914.5800
# 5055    66347.0500
# 5056    71418.1700
# 5057    70104.4000
# 5058    69224.9900
# Name: Close, Length: 5059, dtype: float64

# %%
data['Close'].plot()
# Out:
# <Axes: >

# %%
data.set_index('Start', inplace=True)

# %%
data
# Out:
#                    End        Open        High         Low       Close  \
# Start
# 2010-07-17  2010-07-18      0.0500      0.0500      0.0500      0.0500
# 2010-07-18  2010-07-19      0.0858      0.0858      0.0858      0.0858
# 2010-07-19  2010-07-20      0.0808      0.0808      0.0808      0.0808
# 2010-07-20  2010-07-21      0.0747      0.0747      0.0747      0.0747
# 2010-07-21  2010-07-22      0.0792      0.0792      0.0792      0.0792
# ...                ...         ...         ...         ...         ...
# 2024-05-18  2024-05-19  66939.8200  67376.4100  66640.0100  66914.5800
# 2024-05-19  2024-05-20  66972.6300  67598.3100  66005.3300  66347.0500
# 2024-05-20  2024-05-21  66222.4500  71456.5500  66139.6200  71418.1700
# 2024-05-21  2024-05-22  71369.7300  71739.1400  69266.3800  70104.4000
# 2024-05-22  2024-05-23  70144.6900  70599.9700  69048.6000  69224.9900
#
#                   Volume    Market Cap
# Start
# 2010-07-17  0.000000e+00  0.000000e+00
# 2010-07-18  0.000000e+00  0.000000e+00
# 2010-07-19  0.000000e+00  0.000000e+00
# 2010-07-20  0.000000e+00  0.000000e+00
# 2010-07-21  0.000000e+00  0.000000e+00
# ...                  ...           ...
# 2024-05-18  9.377570e+10  1.318743e+12
# 2024-05-19  8.441685e+10  1.317072e+12
# 2024-05-20  9.769064e+10  1.332128e+12
# 2024-05-21  1.403673e+11  1.391372e+12
# 2024-05-22  1.161000e+11  1.375970e+12
#
# [5059 rows x 7 columns]

# %%
data['Close'].plot()
# Out:
# <Axes: xlabel='Start'>

# %%
np.log1p(data['Close']).plot()
# Out:
# <Axes: xlabel='Start'>

# %%
plt.figure(figsize=(20,6))

plt.subplot(1,2,1)
data['Close'].plot()
plt.title('No scaling')

plt.subplot(1,2,2)
np.log1p(data['Close']).plot()
plt.title('Log scaling')
plt.yscale('log')

# %%
data.head(4)
# Out:
#                    End    Open    High     Low   Close  Volume  Market Cap
# Start
# 2010-07-17  2010-07-18  0.0500  0.0500  0.0500  0.0500     0.0         0.0
# 2010-07-18  2010-07-19  0.0858  0.0858  0.0858  0.0858     0.0         0.0
# 2010-07-19  2010-07-20  0.0808  0.0808  0.0808  0.0808     0.0         0.0
# 2010-07-20  2010-07-21  0.0747  0.0747  0.0747  0.0747     0.0         0.0

# %%
data['Close'].resample('Y').mean()
# Out:
# Start
# 2010-12-31        0.140067
# 2011-12-31        5.642617
# 2012-12-31        8.289260
# 2013-12-31      192.717463
# 2014-12-31      527.241501
# 2015-12-31      272.457795
# 2016-12-31      568.463090
# 2017-12-31     3996.691950
# 2018-12-31     7557.117745
# 2019-12-31     7387.638915
# 2020-12-31    11111.412596
# 2021-12-31    47408.729580
# 2022-12-31    28190.617869
# 2023-12-31    28849.464120
# 2024-12-31    57768.881049
# Freq: A-DEC, Name: Close, dtype: float64

# %%
data['Close'].resample('Y').mean().plot()
# Out:
# <Axes: xlabel='Start'>

# %%
data['Close'].resample('Q').mean().plot()
# Out:
# <Axes: xlabel='Start'>

# %%
data['Close'].resample('M').mean()
# Out:
# Start
# 2010-07-31        0.064267
# 2010-08-31        0.064548
# 2010-09-30        0.061883
# 2010-10-31        0.108774
# 2010-11-30        0.259327
#                   ...
# 2024-01-31    42912.360968
# 2024-02-29    49874.445172
# 2024-03-31    67711.009355
# 2024-04-30    65899.531667
# 2024-05-31    64012.756818
# Freq: M, Name: Close, Length: 167, dtype: float64

# %%
data['Close'].resample('M').mean().plot()
# Out:
# <Axes: xlabel='Start'>

# %%
data['Close_price_pct_change'] = data['Close'].pct_change()*100

# %%
data['Close_price_pct_change']
# Out:
# Start
# 2010-07-17          NaN
# 2010-07-18    71.600000
# 2010-07-19    -5.827506
# 2010-07-20    -7.549505
# 2010-07-21     6.024096
#                 ...
# 2024-05-18    -0.133514
# 2024-05-19    -0.848141
# 2024-05-20     7.643324
# 2024-05-21    -1.839546
# 2024-05-22    -1.254429
# Name: Close_price_pct_change, Length: 5059, dtype: float64

# %%
data['Close_price_pct_change'].plot()
# Out:
# <Axes: xlabel='Start'>

# %%
import chart_studio.plotly as py

import plotly.graph_objs as go

import plotly.express as px

from plotly.offline import download_plotlyjs , init_notebook_mode , plot , iplot
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# !pip install cufflinks
# Out:
# Requirement already satisfied: cufflinks in /Users/haoonkim/anaconda3/lib/python3.11/site-packages (0.17.3)
# Requirement already satisfied: numpy>=1.9.2 in /Users/haoonkim/anaconda3/lib/python3.11/site-packages (from cufflinks) (1.24.3)
# Requirement already satisfied: pandas>=0.19.2 in /Users/haoonkim/anaconda3/lib/python3.11/site-packages (from cufflinks) (2.0.3)
# Requirement already satisfied: plotly>=4.1.1 in /Users/haoonkim/anaconda3/lib/python3.11/site-packages (from cufflinks) (5.9.0)
# Requirement already satisfied: six>=1.9.0 in /Users/haoonkim/anaconda3/lib/python3.11/site-packages (from cufflinks) (1.16.0)
# Requirement already satisfied: colorlover>=0.2.1 in /Users/haoonkim/anaconda3/lib/python3.11/site-packages (from cufflinks) (0.3.0)
# Requirement already satisfied: setuptools>=34.4.1 in /Users/haoonkim/anaconda3/lib/python3.11/site-packages (from cufflinks) (68.0.0)
# Requirement already satisfied: ipython>=5.3.0 in /Users/haoonkim/anaconda3/lib/python3.11/site-packages (from cufflinks) (8.15.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in /Users/haoonkim/anaconda3/lib/python3.11/site-packages (from cufflinks) (8.0.4)
# Requirement already satisfied: backcall in /Users/haoonkim/anaconda3/lib/python3.11/site-packages (from ipython>=5.3.0->cufflinks) (0.2.0)
# Requirement already satisfied: decorator in /Users/haoonkim/anaconda3/lib/python3.11/site-packages (from ipython>=5.3.0->cufflinks) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/haoonkim/anaconda3/lib/python3.11/site-packages (from ipython>=5.3.0->cufflinks) (0.18.1)
# Requirement already satisfied: matplotlib-inline in /Users/haoonkim/anaconda3/lib/python3.11/site-packages (from ipython>=5.3.0->cufflinks) (0.1.6)
# Requirement already satisfied: pickleshare in /Users/haoonkim/anaconda3/lib/python3.11/site-packages (from ipython>=5.3.0->cufflinks) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /Users/haoonkim/anaconda3/lib/python3.11/site-packages (from ipython>=5.3.0->cufflinks) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in /Users/haoonkim/anaconda3/lib/python3.11/site-packages (from ipython>=5.3.0->cufflinks) (2.15.1)
# Requirement already satisfied: stack-data in /Users/haoonkim/anaconda3/lib/python3.11/site-packages (from ipython>=5.3.0->cufflinks) (0.2.0)
# Requirement already satisfied: traitlets>=5 in /Users/haoonkim/anaconda3/lib/python3.11/site-packages (from ipython>=5.3.0->cufflinks) (5.7.1)
# Requirement already satisfied: pexpect>4.3 in /Users/haoonkim/anaconda3/lib/python3.11/site-packages (from ipython>=5.3.0->cufflinks) (4.8.0)
# Requirement already satisfied: appnope in /Users/haoonkim/anaconda3/lib/python3.11/site-packages (from ipython>=5.3.0->cufflinks) (0.1.2)
# Requirement already satisfied: ipykernel>=4.5.1 in /Users/haoonkim/anaconda3/lib/python3.11/site-packages (from ipywidgets>=7.0.0->cufflinks) (6.25.0)
# Requirement already satisfied: widgetsnbextension~=4.0 in /Users/haoonkim/anaconda3/lib/python3.11/site-packages (from ipywidgets>=7.0.0->cufflinks) (4.0.5)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in /Users/haoonkim/anaconda3/lib/python3.11/site-packages (from ipywidgets>=7.0.0->cufflinks) (3.0.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/haoonkim/anaconda3/lib/python3.11/site-packages (from pandas>=0.19.2->cufflinks) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/haoonkim/anaconda3/lib/python3.11/site-packages (from pandas>=0.19.2->cufflinks) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/haoonkim/anaconda3/lib/python3.11/site-packages (from pandas>=0.19.2->cufflinks) (2023.3)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/haoonkim/anaconda3/lib/python3.11/site-packages (from plotly>=4.1.1->cufflinks) (8.2.2)
# Requirement already satisfied: comm>=0.1.1 in /Users/haoonkim/anaconda3/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (0.1.2)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/haoonkim/anaconda3/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/haoonkim/anaconda3/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (7.4.9)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/haoonkim/anaconda3/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (5.3.0)
# Requirement already satisfied: nest-asyncio in /Users/haoonkim/anaconda3/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (1.5.6)
# Requirement already satisfied: packaging in /Users/haoonkim/anaconda3/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (23.1)
# Requirement already satisfied: psutil in /Users/haoonkim/anaconda3/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (5.9.0)
# Requirement already satisfied: pyzmq>=20 in /Users/haoonkim/anaconda3/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (23.2.0)
# Requirement already satisfied: tornado>=6.1 in /Users/haoonkim/anaconda3/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (6.3.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/haoonkim/anaconda3/lib/python3.11/site-packages (from jedi>=0.16->ipython>=5.3.0->cufflinks) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/haoonkim/anaconda3/lib/python3.11/site-packages (from pexpect>4.3->ipython>=5.3.0->cufflinks) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/haoonkim/anaconda3/lib/python3.11/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=5.3.0->cufflinks) (0.2.5)
# Requirement already satisfied: executing in /Users/haoonkim/anaconda3/lib/python3.11/site-packages (from stack-data->ipython>=5.3.0->cufflinks) (0.8.3)
# Requirement already satisfied: asttokens in /Users/haoonkim/anaconda3/lib/python3.11/site-packages (from stack-data->ipython>=5.3.0->cufflinks) (2.0.5)
# Requirement already satisfied: pure-eval in /Users/haoonkim/anaconda3/lib/python3.11/site-packages (from stack-data->ipython>=5.3.0->cufflinks) (0.2.2)
# Requirement already satisfied: entrypoints in /Users/haoonkim/anaconda3/lib/python3.11/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (0.4)
# Requirement already satisfied: platformdirs>=2.5 in /Users/haoonkim/anaconda3/lib/python3.11/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (3.10.0)

# %%
import cufflinks as cf

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
data['Close_price_pct_change']
# Out:
# Start
# 2010-07-17          NaN
# 2010-07-18    71.600000
# 2010-07-19    -5.827506
# 2010-07-20    -7.549505
# 2010-07-21     6.024096
#                 ...
# 2024-05-18    -0.133514
# 2024-05-19    -0.848141
# 2024-05-20     7.643324
# 2024-05-21    -1.839546
# 2024-05-22    -1.254429
# Name: Close_price_pct_change, Length: 5059, dtype: float64

# %%
type(data['Close_price_pct_change'])
# Out:
# pandas.core.series.Series

# %%
data['Close_price_pct_change'].iplot()
# Out:
# <div>                            <div id="9132ff58-e099-4b34-acae-9490032d494d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("